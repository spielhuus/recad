# %%
from IPython.display import display
import recad

import os
print(os.environ['MPLBACKEND'])
# Out:
# module://recad

# %%
# Inverting Amplifier

# %%
schema = recad.Schema("")
schema.move_to((50.8, 50.8))
schema = (schema
    + recad.LocalLabel("Vin").rotate(180) 
    + recad.Wire().right()
    + recad.Symbol("R1", "100k", "Device:R").rotate(90)
    + recad.Junction()
    + recad.Symbol("U1", "TL072", "Amplifier_Operational:LM2904").anchor("2").mirror("x")
    + recad.Junction()
    + recad.Wire().up().length(4)
    + recad.Symbol("R2", "100k", "Device:R").rotate(270).tox("U1", "2")
    + recad.Wire().toy("U1", "2")
    + recad.Symbol("GND", "GND", "power:GND").at("U1", "3")
    + recad.LocalLabel("Vout").at("U1", "1")
)

print(schema)
# Out:
# [__str__] (kicad_sch
# 	(version 20231120)
# 	(generator "recad")
# 	(uuid "14f1997d-af91-4c95-80d4-14663a6aeefe")
# 	(paper "A4")
# 	(title_block)
# 	(lib_symbols
# 		(symbol "Device:R"
# 			(pin_numbers hide)
# 			(pin_names
# 				(offset 0)
# 			)
# 			(exclude_from_sim no)
# 			(in_bom yes)
# 			(on_board yes)
# 			(property "Reference" "R"
# 				(at 2.032 0 90)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 				)
# 			)
# 			(property "Value" "R"
# 				(at 0 0 90)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 				)
# 			)
# 			(property "Footprint" ""
# 				(at -1.778 0 90)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "Datasheet" "~"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "Description" "Resistor"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "ki_keywords" "R res resistor"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "ki_fp_filters" "R_*"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(symbol "R_0_1"
# 				(rectangle
# 					(start -1.016 -2.54)
# 					(end 1.016 2.54)
# 					(stroke
# 						(width 0.254)
# 						(type default)
# 					)
# 					(fill
# 						(type none)
# 					)
# 				)
# 			)
# 			(symbol "R_1_1"
# 				(pin passive line
# 					(at 0 3.81 270)
# 					(length 1.27)
# 					(name "~"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "1"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 				(pin passive line
# 					(at 0 -3.81 90)
# 					(length 1.27)
# 					(name "~"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "2"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 			)
# 		)
# 		(symbol "Amplifier_Operational:LM2904"
# 			(pin_names
# 				(offset 0.127)
# 			)
# 			(exclude_from_sim no)
# 			(in_bom yes)
# 			(on_board yes)
# 			(property "Reference" "U"
# 				(at 0 5.08 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(justify left)
# 				)
# 			)
# 			(property "Value" "LM2904"
# 				(at 0 -5.08 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(justify left)
# 				)
# 			)
# 			(property "Footprint" ""
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "Datasheet" "http://www.ti.com/lit/ds/symlink/lm358.pdf"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "Description" "Dual Operational Amplifiers, DIP-8/SOIC-8/TSSOP-8/VSSOP-8"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "ki_locked" ""
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 				)
# 			)
# 			(property "ki_keywords" "dual opamp"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "ki_fp_filters" "SOIC*3.9x4.9mm*P1.27mm* DIP*W7.62mm* TO*99* OnSemi*Micro8* TSSOP*3x3mm*P0.65mm* TSSOP*4.4x3mm*P0.65mm* MSOP*3x3mm*P0.65mm* SSOP*3.9x4.9mm*P0.635mm* LFCSP*2x2mm*P0.5mm* *SIP* SOIC*5.3x6.2mm*P1.27mm*"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(symbol "LM2904_1_1"
# 				(polyline
# 					(pts
# 						(xy -5.08 5.08)
# 						(xy 5.08 0)
# 						(xy -5.08 -5.08)
# 						(xy -5.08 5.08)
# 					)
# 					(stroke
# 						(width 0.254)
# 						(type default)
# 					)
# 					(fill
# 						(type background)
# 					)
# 				)
# 				(pin output line
# 					(at 7.62 0 180)
# 					(length 2.54)
# 					(name "~"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "1"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 				(pin input line
# 					(at -7.62 -2.54 0)
# 					(length 2.54)
# 					(name "-"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "2"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 				(pin input line
# 					(at -7.62 2.54 0)
# 					(length 2.54)
# 					(name "+"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "3"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 			)
# 			(symbol "LM2904_2_1"
# 				(polyline
# 					(pts
# 						(xy -5.08 5.08)
# 						(xy 5.08 0)
# 						(xy -5.08 -5.08)
# 						(xy -5.08 5.08)
# 					)
# 					(stroke
# 						(width 0.254)
# 						(type default)
# 					)
# 					(fill
# 						(type background)
# 					)
# 				)
# 				(pin input line
# 					(at -7.62 2.54 0)
# 					(length 2.54)
# 					(name "+"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "5"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 				(pin input line
# 					(at -7.62 -2.54 0)
# 					(length 2.54)
# 					(name "-"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "6"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 				(pin output line
# 					(at 7.62 0 180)
# 					(length 2.54)
# 					(name "~"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "7"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 			)
# 			(symbol "LM2904_3_1"
# 				(pin power_in line
# 					(at -2.54 -7.62 90)
# 					(length 3.81)
# 					(name "V-"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "4"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 				(pin power_in line
# 					(at -2.54 7.62 270)
# 					(length 3.81)
# 					(name "V+"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "8"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 			)
# 		)
# 		(symbol "power:GND"
# 			(power)
# 			(pin_numbers hide)
# 			(pin_names
# 				(offset 0) hide
# 			)
# 			(exclude_from_sim no)
# 			(in_bom yes)
# 			(on_board yes)
# 			(property "Reference" "#PWR"
# 				(at 0 -6.35 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "Value" "GND"
# 				(at 0 -3.81 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 				)
# 			)
# 			(property "Footprint" ""
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "Datasheet" ""
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "Description" "Power symbol creates a global label with name \"GND\" , ground"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(property "ki_keywords" "global power"
# 				(at 0 0 0)
# 				(effects
# 					(font
# 						(size 1.27 1.27)
# 					)
# 					(hide yes)
# 				)
# 			)
# 			(symbol "GND_0_1"
# 				(polyline
# 					(pts
# 						(xy 0 0)
# 						(xy 0 -1.27)
# 						(xy 1.27 -1.27)
# 						(xy 0 -2.54)
# 						(xy -1.27 -1.27)
# 						(xy 0 -1.27)
# 					)
# 					(stroke
# 						(width 0)
# 						(type default)
# 					)
# 					(fill
# 						(type none)
# 					)
# 				)
# 			)
# 			(symbol "GND_1_1"
# 				(pin power_in line
# 					(at 0 0 270)
# 					(length 0)
# 					(name "~"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 					(number "1"
# 						(effects
# 							(font
# 								(size 1.27 1.27)
# 							)
# 						)
# 					)
# 				)
# 			)
# 		)
# 	)
# 	(label "Vin"
# 		(at 50.8 50.8 180)
# 		(effects
# 			(font
# 				(size 1.27 1.27)
# 			)
# 			(justify right bottom)
# 		)
# 		(uuid "7683d657-7903-489a-b563-82d97549c2ee")
# 	)
# 	(wire
# 		(pts
# 			(xy 50.8 50.8)
# 			(xy 53.34 50.8)
# 		)
# 		(stroke
# 			(width 0)
# 		)
# 		(uuid "b076ea2f-8bec-47d7-89ad-4b437655853f")
# 	)
# 	(symbol
# 		(lib_id "Device:R")
# 		(at 57.15 50.8 90)
# 		(unit 1)
# 		(exclude_from_sim no)
# 		(in_bom yes)
# 		(on_board yes)
# 		(dnp no)
# 		(uuid "4f8c815a-2fb5-4c85-9f56-16186bdd07b2")
# 		(property "Reference" "R1"
# 			(at 57.15 46.034 90)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 			)
# 		)
# 		(property "Value" "100k"
# 			(at 57.15 48.534 90)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 			)
# 		)
# 		(property "Footprint" ""
# 			(at -1.778 0 90)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Datasheet" "~"
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Description" "Resistor"
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(pin "1"
# 			(uuid "5d98a260-88b0-4dc2-ba1f-cb3fa608694a")
# 		)
# 		(pin "2"
# 			(uuid "408a2b12-0d28-489d-b60d-e5ebb9eb477c")
# 		)
# 		(instances
# 			(project ""
# 				(path "/14f1997d-af91-4c95-80d4-14663a6aeefe"
# 					(reference "R1")
# 					(unit 1)
# 				)
# 			)
# 		)
# 	)
# 	(junction
# 		(at 60.96 50.8)
# 		(diameter 0)
# 		(color 0 0 0 0)
# 		(uuid "7a4489d5-5b35-42f8-a8b6-ed50db98f409")
# 	)
# 	(symbol
# 		(lib_id "Amplifier_Operational:LM2904")
# 		(at 68.58 53.34 0)
# 		(mirror x)
# 		(unit 1)
# 		(exclude_from_sim no)
# 		(in_bom yes)
# 		(on_board yes)
# 		(dnp no)
# 		(uuid "d620fb81-3d55-4af1-a59b-55bf7ff5f721")
# 		(property "Reference" "U1"
# 			(at 68.58 44.51 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 			)
# 		)
# 		(property "Value" "TL072"
# 			(at 68.58 47.01 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 			)
# 		)
# 		(property "Footprint" ""
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Datasheet" "http://www.ti.com/lit/ds/symlink/lm358.pdf"
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Description" "Dual Operational Amplifiers, DIP-8/SOIC-8/TSSOP-8/VSSOP-8"
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(pin "1"
# 			(uuid "0dc01932-63d3-4fe6-880a-5aad5b474b19")
# 		)
# 		(pin "2"
# 			(uuid "56926786-19e4-46f0-bfe1-4a74482fc729")
# 		)
# 		(pin "3"
# 			(uuid "a95660ce-1b38-4776-9b7b-3c440b015485")
# 		)
# 		(instances
# 			(project ""
# 				(path "/14f1997d-af91-4c95-80d4-14663a6aeefe"
# 					(reference "U1")
# 					(unit 1)
# 				)
# 			)
# 		)
# 	)
# 	(junction
# 		(at 76.2 53.34)
# 		(diameter 0)
# 		(color 0 0 0 0)
# 		(uuid "e44731c3-c3fd-417a-a012-24759918afb4")
# 	)
# 	(wire
# 		(pts
# 			(xy 76.2 53.34)
# 			(xy 76.2 43.18)
# 		)
# 		(stroke
# 			(width 0)
# 		)
# 		(uuid "9b3cead8-016c-4227-a1e5-2fad090d3044")
# 	)
# 	(wire
# 		(pts
# 			(xy 76.2 43.18)
# 			(xy 72.39 43.18)
# 		)
# 		(stroke
# 			(width 0)
# 		)
# 		(uuid "87ef2746-5642-497f-8459-5b4af342d928")
# 	)
# 	(wire
# 		(pts
# 			(xy 60.96 43.18)
# 			(xy 64.77 43.18)
# 		)
# 		(stroke
# 			(width 0)
# 		)
# 		(uuid "a5f7c966-320a-4e6c-909d-ce87ced6e863")
# 	)
# 	(symbol
# 		(lib_id "Device:R")
# 		(at 68.58 43.18 270)
# 		(unit 1)
# 		(exclude_from_sim no)
# 		(in_bom yes)
# 		(on_board yes)
# 		(dnp no)
# 		(uuid "b505f0b6-fc37-464d-a869-fdc6b8f12bb7")
# 		(property "Reference" "R2"
# 			(at 68.58 38.414 90)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 			)
# 		)
# 		(property "Value" "100k"
# 			(at 68.58 40.914 90)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 			)
# 		)
# 		(property "Footprint" ""
# 			(at -1.778 0 90)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Datasheet" "~"
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Description" "Resistor"
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(pin "1"
# 			(uuid "03b40332-863e-459b-ba27-615371aa563d")
# 		)
# 		(pin "2"
# 			(uuid "88b19915-9b88-4301-ada6-e99996887342")
# 		)
# 		(instances
# 			(project ""
# 				(path "/14f1997d-af91-4c95-80d4-14663a6aeefe"
# 					(reference "R2")
# 					(unit 1)
# 				)
# 			)
# 		)
# 	)
# 	(wire
# 		(pts
# 			(xy 60.96 43.18)
# 			(xy 60.96 50.8)
# 		)
# 		(stroke
# 			(width 0)
# 		)
# 		(uuid "793c2307-950a-4982-9c5f-e69f80bf394e")
# 	)
# 	(symbol
# 		(lib_id "power:GND")
# 		(at 60.96 55.88 0)
# 		(unit 1)
# 		(exclude_from_sim no)
# 		(in_bom yes)
# 		(on_board yes)
# 		(dnp no)
# 		(uuid "1e2864f6-59ab-4233-b5b7-6c4b72e36431")
# 		(property "Reference" "#PWR01"
# 			(at 0 -6.35 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Value" "GND"
# 			(at 60.96 59.67 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 			)
# 		)
# 		(property "Footprint" ""
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Datasheet" ""
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(property "Description" "Power symbol creates a global label with name \"GND\" , ground"
# 			(at 0 0 0)
# 			(effects
# 				(font
# 					(size 1.27 1.27)
# 				)
# 				(hide yes)
# 			)
# 		)
# 		(pin "1"
# 			(uuid "5d96e2b5-b188-4500-b244-003472c98a5b")
# 		)
# 		(instances
# 			(project ""
# 				(path "/14f1997d-af91-4c95-80d4-14663a6aeefe"
# 					(reference "#PWR01")
# 					(unit 1)
# 				)
# 			)
# 		)
# 	)
# 	(label "Vout"
# 		(at 76.2 53.34 0)
# 		(effects
# 			(font
# 				(size 1.27 1.27)
# 			)
# 			(justify left bottom)
# 		)
# 		(uuid "dd658c50-e648-4b13-82cf-499f4201d961")
# 	)
# 	(sheet_instances
# 		(path "/"
# 			(page "1")
# 		)
# 	)
# )

# %%
schema.plot()
